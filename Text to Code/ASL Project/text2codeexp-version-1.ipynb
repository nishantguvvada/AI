# %% [markdown]
# # Text to Code Explanation

# %%
import sys
# !{sys.executable} -m pip install --upgrade --user google-cloud-aiplatform google-cloud-storage 'google-cloud-bigquery[pandas]'
# Out:
# Requirement already satisfied: google-cloud-aiplatform in /opt/conda/lib/python3.10/site-packages (1.26.0)
# Collecting google-cloud-aiplatform
#   Using cached google_cloud_aiplatform-1.36.4-py2.py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: google-cloud-storage in /home/jupyter/.local/lib/python3.10/site-packages (2.13.0)
# Requirement already satisfied: google-cloud-bigquery[pandas] in /home/jupyter/.local/lib/python3.10/site-packages (3.13.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.34.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.22.3)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (3.20.3)
# Requirement already satisfied: packaging>=14.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (23.1)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.10.4)
# Requirement already satisfied: shapely<3.0.0dev in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.8.5.post1)
# Requirement already satisfied: google-auth<3.0dev,>=2.23.3 in /home/jupyter/.local/lib/python3.10/site-packages (from google-cloud-storage) (2.23.4)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (2.3.3)
# Requirement already satisfied: google-resumable-media>=2.6.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (2.6.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (2.31.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (1.5.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.47.0 in /home/jupyter/.local/lib/python3.10/site-packages (from google-cloud-bigquery[pandas]) (1.59.2)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery[pandas]) (2.8.2)
# Requirement already satisfied: pandas>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery[pandas]) (1.5.3)
# Requirement already satisfied: pyarrow>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery[pandas]) (9.0.0)
# Requirement already satisfied: db-dtypes<2.0.0dev,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery[pandas]) (1.1.1)
# Requirement already satisfied: numpy>=1.16.6 in /opt/conda/lib/python3.10/site-packages (from db-dtypes<2.0.0dev,>=0.3.0->google-cloud-bigquery[pandas]) (1.22.4)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.60.0)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /home/jupyter/.local/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.47.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0dev,>=2.23.3->google-cloud-storage) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0dev,>=2.23.3->google-cloud-storage) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0dev,>=2.23.3->google-cloud-storage) (4.9)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /opt/conda/lib/python3.10/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.12.6)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.0->google-cloud-bigquery[pandas]) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery[pandas]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2023.7.22)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.23.3->google-cloud-storage) (0.5.0)
# Using cached google_cloud_aiplatform-1.36.4-py2.py3-none-any.whl (3.3 MB)
# Installing collected packages: google-cloud-aiplatform
# Successfully installed google-cloud-aiplatform-1.36.4

# %%
# restart kernel after installs so that your environment can access the new packages
import IPython

app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %% [markdown]
# **Set Environment Variables**

# %%
# get project ID
PROJECT_ID = ! gcloud config get project
#PROJECT_ID = 'qwiklabs-asl-04-06351f77b64f'
PROJECT_ID = PROJECT_ID[0]
LOCATION = "us-central1"
if PROJECT_ID == "(unset)":
    print(f"Please set the project ID manually below")

# %%
# define project information
if PROJECT_ID == "(unset)":
    PROJECT_ID = "qwiklabs-asl-04-06351f77b64f" # @param {type:"string"}

# generate an unique id for this session
from datetime import datetime
UID = datetime.now().strftime("%m%d%H%M")

# %%
#! gcloud services enable compute.googleapis.com aiplatform.googleapis.com storage.googleapis.com bigquery.googleapis.com --project {PROJECT_ID}

# %% [markdown]
# **Data Preparation**

# %%
import pandas as pd
from google.cloud import bigquery

bq_client = bigquery.Client(project=PROJECT_ID)
QUERY_TEMPLATE = """
        SELECT *
        FROM `qwiklabs-asl-04-e7ad74c2e059".rax_dataset_metadata.table_metadata`
        UNION ALL
        SELECT *
        FROM `qwiklabs-asl-04-e7ad74c2e059".rax_dataset_metadata.procedure_metadata`
        """
query = QUERY_TEMPLATE.format()
query_job = bq_client.query(QUERY_TEMPLATE)
rows = query_job.result()
df = rows.to_dataframe()

# examine the data
df.head()
# Out:
#       table_schema                          table_name  \
# 0  rax_bq_metadata                         account_ran
# 1  rax_bq_metadata        email_apps_tax_detail_report
# 2  rax_bq_metadata  dctm_comments_assignments_and_work
# 3  rax_bq_metadata                               wismo
# 4  rax_bq_metadata          bt_pipeline_waterfall_week
#
#                                                  ddl
# 0  CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...
# 1  CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...
# 2  CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...
# 3  CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...
# 4  CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...

# %% [markdown]
# **Call the API to generate embeddings**
#
# We will use the ddl column and generate embedding for it with Embeddings for Text API

# %%
# init the vertexai package
import vertexai
vertexai.init(project=PROJECT_ID, location=LOCATION)

# %%
# Load the text embeddings model
from vertexai.preview.language_models import TextEmbeddingModel
model = TextEmbeddingModel.from_pretrained("textembedding-gecko@001")

# %% [markdown]
# Printing for loop to understand tqdm

# %%
import tqdm
texts = [1,2,3,4,5,9,7,8,9,10,11,12,13,14,21,16]
for i in tqdm.tqdm(range(0, len(texts), 5)):
    print(texts[i:i + 5])
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 25191.02it/s]
# [1, 2, 3, 4, 5]
# [9, 7, 8, 9, 10]
# [11, 12, 13, 14, 21]
# [16]

# %%
import time
import tqdm # to show a progress bar

# get embeddings for a list of texts
BATCH_SIZE = 5
def get_embeddings_wrapper(texts):
    embs = [] # creating an empty list to store embeddings
    for i in tqdm.tqdm(range(0, len(texts), BATCH_SIZE)): # looping from 0 till the length of texts with a step of BATCH_SIZE = 5 (0, 5, 10, 15...)
        time.sleep(1) # to avoid the quota error
        result = model.get_embeddings(texts[i:i + BATCH_SIZE]) # get embeddings for a batch of texts defined by i and i + BATCH_SIZE (0:0+5, 5:5+5, 10:10+5...)
        embs = embs + [e.values for e in result] # storing the values returned by the get_embeddings function in the embs empty list
    return embs

# %%
# get embeddings for the ddl column and add them as "embedding" column in the dataframe
df = df.assign(embedding=get_embeddings_wrapper(list(df.ddl)))
df.head()

# %% [markdown]
# **Calculating Similarities - how these embeddings are organized in the embedding space with their meanings**
#
# Calculate similarity between two embeddings by using one of the popular metrics like L2 distance, cosine similarity, inner product

# %%
import random
import numpy as np

# pick one of them as a key code
key = random.randint(0, len(df))

# calculate dot product between the key and other ddl
embs = np.array(df.embedding.to_list())
similarities = np.dot(embs[key], embs.T)

# print similarities for the first 5 codes
similarities[:5]
# Out:
# array([0.85769618, 0.83066232, 0.9086    , 0.91825791, 0.87504539])

# %%
# print the codes
print(f"Key code: {df.ddl[key]}\n")

# sort and print the code by similarities
sorted_code = sorted(zip(df.ddl, similarities), key=lambda x: x[1], reverse=True)[:20]
for i, (code, similarity) in enumerate(sorted_code):
    print(f"{similarity:.4f} {code}")
# Out:
# Key code: CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.email_apps_tax_detail_report`
# (
#   account_number STRING,
#   customer_name STRING,
#   address STRING,
#   city STRING,
#   state STRING,
#   zip STRING,
#   country STRING,
#   invoice_number STRING,
#   invoiceyearmonth STRING,
#   created_t DATETIME,
#   invoice_date STRING,
#   invoice_amount FLOAT64,
#   invoice_balance FLOAT64,
#   currency STRING
# )
# PARTITION BY DATETIME_TRUNC(created_t, MONTH)
# CLUSTER BY country, customer_name, account_number, invoice_number
# OPTIONS(
#   require_partition_filter=true
# );
#
# 1.0000 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.email_apps_tax_detail_report`
# (
#   account_number STRING,
#   customer_name STRING,
#   address STRING,
#   city STRING,
#   state STRING,
#   zip STRING,
#   country STRING,
#   invoice_number STRING,
#   invoiceyearmonth STRING,
#   created_t DATETIME,
#   invoice_date STRING,
#   invoice_amount FLOAT64,
#   invoice_balance FLOAT64,
#   currency STRING
# )
# PARTITION BY DATETIME_TRUNC(created_t, MONTH)
# CLUSTER BY country, customer_name, account_number, invoice_number
# OPTIONS(
#   require_partition_filter=true
# );
# 0.9621 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.agg_spend_final_product_detail`
# (
#   time_month INT64 NOT NULL,
#   date DATE,
#   account STRING,
#   server STRING,
#   dc STRING,
#   customer STRING,
#   product_type STRING,
#   invoice_amount NUMERIC,
#   transaction_type STRING,
#   currency STRING,
#   product_for_discount STRING
# )
# PARTITION BY date
# CLUSTER BY transaction_type, customer, dc, product_type
# OPTIONS(
#   require_partition_filter=true
# );
# 0.9495 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.device_unit_price`
# (
#   unit_price_time_month_key INT64 NOT NULL,
#   invoice_date DATE,
#   account_number STRING,
#   account_type STRING,
#   device_number STRING,
#   invoice_unit_price NUMERIC,
#   core_unit_price NUMERIC,
#   difference NUMERIC
# )
# PARTITION BY invoice_date
# CLUSTER BY account_type, account_number, device_number
# OPTIONS(
#   require_partition_filter=true
# );
# 0.9438 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.account360_executivesponsor`
# (
#   account_id STRING,
#   is_active BOOL,
#   executive_sponsor_tmk INT64,
#   executive_sponsor_long_id STRING,
#   executive_sponsor_short_id STRING,
#   executive_sponsor_type STRING,
#   current_executive_sponsor STRING,
#   createddate DATETIME
# )
# PARTITION BY DATETIME_TRUNC(createddate, MONTH)
# CLUSTER BY executive_sponsor_type, executive_sponsor_tmk, current_executive_sponsor, account_id
# OPTIONS(
#   require_partition_filter=true
# );
# 0.9394 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.account360_account_data`
# (
#   account_number STRING,
#   account_type STRING,
#   account_id STRING,
#   company_name STRING,
#   company_name_filter_a STRING,
#   company_name_filter_b STRING,
#   top_200_salesforce BOOL,
#   naics_description STRING,
#   discoverorgid STRING,
#   parent_id STRING,
#   account_identifier STRING,
#   date_partition DATE
# )
# PARTITION BY DATE_TRUNC(date_partition, MONTH)
# CLUSTER BY account_type, account_number, account_identifier, account_id;
# 0.9367 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.appformix`
# (
#   appformix_date DATE,
#   appformix_device_number NUMERIC,
#   appformix_device_name STRING,
#   appformix_device_status STRING,
#   appformix_device_type STRING,
#   appformix_device_datacenter STRING,
#   appformix_device_online_date DATETIME,
#   appformix_sku_number STRING,
#   appformix_sku_name STRING,
#   appformix_sku_description STRING,
#   node_role STRING,
#   openstack_role STRING,
#   appformixaccount_number STRING,
#   appformix_account_name STRING,
#   appformix_account_manager STRING,
#   appformix_account_type STRING,
#   appformix_account_sub_type STRING,
#   appformix_account_status STRING,
#   appformix_account_billing_postal_code STRING,
#   account_billing_country STRING,
#   appformix_account_team STRING
# )
# PARTITION BY DATE_TRUNC(appformix_date, MONTH)
# CLUSTER BY appformix_device_status, appformix_device_type, appformix_account_status, appformix_account_team
# OPTIONS(
#   require_partition_filter=true
# );
# 0.9360 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.account360_tasks`
# (
#   task_id STRING,
#   task_type STRING,
#   task_subject STRING,
#   task_status STRING,
#   task_description STRING,
#   task_date DATETIME,
#   task_rackers STRING,
#   tmk INT64,
#   activity_owner STRING,
#   account_id STRING,
#   task_name STRING
# )
# PARTITION BY DATETIME_TRUNC(task_date, MONTH)
# CLUSTER BY task_type, tmk, account_id, task_id
# OPTIONS(
#   require_partition_filter=true
# );
# 0.9359 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.aws_recon_nrd`
# (
#   total_invoiced FLOAT64,
#   aws_flag BOOL,
#   nrd_invoice_tmk DATE,
#   prepaid BOOL,
#   account_number STRING,
#   account_name STRING,
#   line_of_business STRING,
#   team_sub_segment STRING,
#   invoice_no STRING,
#   invoice_line_item_source STRING,
#   gl_account STRING,
#   gl_account_description STRING,
#   gl_product_code STRING,
#   gl_product_description STRING,
#   product_group STRING,
#   product_type STRING,
#   currency STRING,
#   usage_month DATE,
#   nrd_tmk DATE
# )
# PARTITION BY nrd_tmk
# CLUSTER BY gl_account, account_number, product_group, product_type;
# 0.9351 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.contract_compliance`
# (
#   salesforce_opp_id STRING,
#   core_account_number STRING,
#   account_name_sf STRING,
#   contracting_entity_different STRING,
#   contracting_entity_match STRING,
#   entity_name_brm STRING,
#   entity_name_sf STRING,
#   entity_raptor STRING,
#   org STRING,
#   close_date_sf DATE,
#   contracting_law_region STRING,
#   account_status STRING
# )
# PARTITION BY DATE_TRUNC(close_date_sf, MONTH)
# CLUSTER BY salesforce_opp_id, core_account_number
# OPTIONS(
#   require_partition_filter=true
# );
# 0.9331 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.dctm_status_transition`
# (
#   transition_id INT64,
#   build_time_key INT64,
#   transition_timestamp DATETIME,
#   hour INT64,
#   date_group DATE,
#   datacenter STRING,
#   new_status_number INT64,
#   server_status STRING,
#   tech_id INT64,
#   tech_name STRING,
#   device_number INT64,
#   account_number INT64,
#   device_os STRING,
#   shift STRING,
#   year_month INT64
# )
# PARTITION BY DATETIME_TRUNC(transition_timestamp, MONTH)
# CLUSTER BY account_number, date_group, datacenter, device_os
# OPTIONS(
#   require_partition_filter=true
# );
# 0.9317 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.closure_codes_closed_tickets`
# (
#   _tmk_sso STRING,
#   time_key FLOAT64,
#   kpi_time_key FLOAT64,
#   ticket_number STRING,
#   kpi_vehicle_source STRING,
#   Ticket_Status STRING,
#   kpi_racker_sso STRING,
#   kpi_dst_date DATETIME,
#   kpi_dst_hour FLOAT64,
#   _source_account_number STRING,
#   kpi_account_number STRING,
#   department STRING,
#   product STRING,
#   area STRING,
#   closure_code STRING,
#   has_cc FLOAT64,
#   cc_dst_date DATETIME,
#   username STRING,
#   service_request_type STRING,
#   unsupported_work BOOL,
#   iaw_script_used BOOL,
#   script_version STRING,
#   is_last_access FLOAT64,
#   last_access_days FLOAT64,
#   year_month_day_key FLOAT64,
#   year_month_key FLOAT64,
#   year_week_key FLOAT64,
#   full_date DATETIME,
#   year_number FLOAT64,
#   day_of_year_number FLOAT64,
#   year_dash_quarter_number STRING,
#   quarter_number FLOAT64,
#   month_number FLOAT64,
#   day_of_month_number FLOAT64,
#   month_abbreviation STRING,
#   week_number FLOAT64,
#   day_of_week_number FLOAT64,
#   day_of_week STRING
# )
# PARTITION BY DATETIME_TRUNC(full_date, MONTH)
# CLUSTER BY department, area, product
# OPTIONS(
#   require_partition_filter=true
# );
# 0.9311 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.alert_logic`
# (
#   account_billing_country STRING,
#   account_billing_postal_code STRING,
#   account_manager STRING,
#   account_name STRING,
#   account_number INT64,
#   account_status STRING,
#   account_sub_type STRING,
#   account_team STRING,
#   account_type STRING,
#   actual_end_date DATE,
#   attributename STRING,
#   attributevalue STRING,
#   device_cancellation_date DATE,
#   device_create_date DATE,
#   device_datacenter STRING,
#   device_mrr FLOAT64,
#   device_name STRING,
#   device_number INT64,
#   device_offline_date DATE,
#   device_online_date DATE,
#   device_os STRING,
#   device_placed_order_date DATE,
#   device_region STRING,
#   device_status STRING,
#   device_type STRING,
#   devicenumkey INT64,
#   finaldate DATE,
#   initial_contract_end_date DATE,
#   initial_contract_received_date DATE,
#   initial_contract_term INT64,
#   latest_renewal_date DATE,
#   latest_renewal_end_date DATE,
#   latest_renewal_term INT64,
#   offering_label STRING,
#   platform_name STRING,
#   platform_sku INT64,
#   rms_account_level_sku_description STRING,
#   rms_account_level_sku_number INT64,
#   run_date DATE,
#   run_month STRING,
#   run_year INT64,
#   sku_description STRING,
#   sku_name STRING,
#   sku_number INT64,
#   time_key DATE,
#   yearmonth INT64
# )
# PARTITION BY time_key
# CLUSTER BY account_number, device_number, sku_number, devicenumkey
# OPTIONS(
#   require_partition_filter=true
# );
# 0.9302 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.aws_recon_ap_invoices`
# (
#   invoice_id STRING,
#   invoice_num STRING,
#   invoice_currency_code STRING,
#   invoice_amount FLOAT64,
#   description STRING,
#   usage_start_date_raw STRING,
#   usage_end_date_raw STRING,
#   pre_paid BOOL,
#   creation_month DATE,
#   master_payer_count INT64,
#   invoice_amount_prorated FLOAT64,
#   date_format STRING,
#   invoice_date DATE,
#   master_payer STRING,
#   usage_start_date DATE,
#   usage_end_date DATE,
#   ap_usage_tmk DATE,
#   comment_time_stamp TIMESTAMP,
#   commenter STRING,
#   invoice_comment STRING
# )
# PARTITION BY ap_usage_tmk
# CLUSTER BY master_payer;
# 0.9293 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.customer_call_experience_dim_time`
# (
#   initiation_time_key INT64,
#   time_key INT64,
#   year_month_day_key INT64,
#   year_month_key INT64,
#   year_week_key INT64,
#   year_week_key_legacy INT64,
#   full_date DATETIME,
#   year_number INT64,
#   day_of_year_number INT64,
#   year_dash_quarter_number STRING,
#   quarter_number INT64,
#   month_number INT64,
#   day_of_month_number INT64,
#   month_abbreviation STRING,
#   week_number INT64,
#   day_of_week_number INT64,
#   day_of_week STRING
# )
# PARTITION BY DATETIME_TRUNC(full_date, MONTH)
# CLUSTER BY year_number, full_date;
# 0.9290 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.account_contact`
# (
#   account_number STRING NOT NULL,
#   account_type STRING NOT NULL,
#   contact_type STRING NOT NULL,
#   contact_role STRING NOT NULL,
#   contact_full_name STRING,
#   contact_email STRING,
#   contact_phone STRING,
#   contact_country STRING,
#   contact_state STRING,
#   contact_city STRING,
#   contact_postal_code STRING,
#   contact_street STRING,
#   date_partition DATE
# )
# PARTITION BY date_partition
# CLUSTER BY account_type, contact_type, contact_role, account_number;
# 0.9286 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.device`
# (
#   account_number STRING NOT NULL,
#   account_type STRING NOT NULL,
#   device_number INT64 NOT NULL,
#   device_status STRING NOT NULL,
#   device_online_date TIMESTAMP,
#   device_offline_date TIMESTAMP,
#   device_online_status STRING,
#   device_type STRING,
#   device_usage_type STRING,
#   device_make_model STRING,
#   device_host_name STRING,
#   device_os STRING,
#   device_os_name STRING,
#   device_os_version STRING,
#   device_nickname STRING,
#   device_contract_end_date TIMESTAMP,
#   device_contract_received_date TIMESTAMP,
#   device_last_contract_renewal_date TIMESTAMP,
#   device_record_effective_start_date DATE NOT NULL,
#   device_record_effective_end_date DATE NOT NULL,
#   device_record_effective_start_datetime TIMESTAMP NOT NULL,
#   device_record_effective_end_datetime TIMESTAMP NOT NULL,
#   device_current_record_flag INT64
# )
# PARTITION BY DATE_TRUNC(device_record_effective_start_date, MONTH)
# CLUSTER BY device_current_record_flag, device_status, account_number, device_number;
# 0.9283 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.ticket_core`
# (
#   account_number STRING,
#   account_type STRING,
#   ticket_id STRING NOT NULL,
#   ticket_status_current STRING,
#   ticket_created_date_time TIMESTAMP,
#   ticket_created_type STRING,
#   ticket_created_by STRING,
#   ticket_subject STRING,
#   ticket_severity STRING,
#   ticket_public_private STRING,
#   ticket_url STRING
# )
# PARTITION BY TIMESTAMP_TRUNC(ticket_created_date_time, MONTH)
# CLUSTER BY ticket_created_type, ticket_status_current, account_number, ticket_id;
# 0.9278 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.account_sku`
# (
#   account_number STRING NOT NULL,
#   account_type STRING NOT NULL,
#   account_sku_number INT64 NOT NULL,
#   account_sku_name STRING,
#   account_sku_description STRING,
#   account_sku_product_label STRING,
#   account_sku_detail STRING,
#   account_sku_label STRING,
#   date_partition DATE
# )
# PARTITION BY date_partition
# CLUSTER BY account_sku_product_label, account_sku_name, account_sku_number, account_number;
# 0.9272 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.assigned_rackers`
# (
#   account_number STRING,
#   account_type STRING NOT NULL,
#   racker_sso STRING,
#   racker_name STRING,
#   racker_role STRING,
#   sfdc_user_id STRING,
#   assignment_start_date DATE,
#   assignment_end_date DATE,
#   assignment_current_record INT64
# )
# PARTITION BY DATE_TRUNC(assignment_start_date, MONTH)
# CLUSTER BY assignment_current_record, racker_role, racker_sso, account_number;
# 0.9262 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.churn_vm`
# (
#   account_number STRING NOT NULL,
#   account_team_name STRING,
#   account_manager STRING,
#   account_bdc STRING,
#   team_name_ssl STRING,
#   churn_level_1 STRING,
#   churn_level_2 STRING,
#   churn_level_3 STRING,
#   oracle_team_id STRING,
#   customer_name STRING,
#   customer_number STRING,
#   device_number STRING,
#   product STRING,
#   ymk_last_month STRING,
#   dist_amt_last FLOAT64,
#   ymk_current_month STRING,
#   dist_amt_current FLOAT64,
#   amt FLOAT64,
#   time_loaded TIMESTAMP
# )
# PARTITION BY DATE(time_loaded)
# CLUSTER BY customer_name, account_number, customer_number, device_number;

# %% [markdown]
# Creating an index column named "id"

# %%
df['id']= df.index

# %%
df
# Out:
#         table_schema                          table_name  \
# 0    rax_bq_metadata                         account_ran
# 1    rax_bq_metadata        email_apps_tax_detail_report
# 2    rax_bq_metadata  dctm_comments_assignments_and_work
# 3    rax_bq_metadata                               wismo
# 4    rax_bq_metadata          bt_pipeline_waterfall_week
# ..               ...                                 ...
# 172  rax_bq_metadata                 rev_mat_opps_detail
# 173  rax_bq_metadata                   retention_rate_ib
# 174  rax_bq_metadata                      vw_alert_logic
# 175  rax_bq_metadata                 device_availability
# 176  rax_bq_metadata           opportunity_open_live_mpc
#
#                                                    ddl   id
# 0    CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...    0
# 1    CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...    1
# 2    CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...    2
# 3    CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...    3
# 4    CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...    4
# ..                                                 ...  ...
# 172  CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...  172
# 173  CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...  173
# 174  CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...  174
# 175  CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...  175
# 176  CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...  176
#
# [177 rows x 4 columns]

# %% [markdown]
# **Save the embeddings in a JSON file**

# %%
# save id and embedding as a json file
jsonl_string = df[['id', 'embedding']].to_json(orient = 'records', lines = True)
with open('codeexplanation.json', 'w') as f:
    f.write(jsonl_string)

# show the first few lines of the json file
! head -n 3 codeexplanation.json
# Out:
# {"id":0,"embedding":[-0.04515706,-0.050130114,-0.0235803258,0.0279327407,0.0156944953,-0.0556662232,0.0481634364,0.0071523716,-0.0035243982,0.0208040178,-0.0236611869,-0.0038096062,0.0067580477,0.0349338874,0.0257413834,-0.0190424006,-0.0004454835,0.0052142483,0.0196017455,0.0175804514,-0.0364599153,-0.0447966419,0.0103281904,0.0130845457,-0.0111046173,-0.0844000727,0.002823195,-0.0309756454,-0.0660549551,0.0337891951,-0.0487467349,0.0079384409,-0.0629910007,-0.0040504043,0.020544529,0.0205559842,-0.0008966839,0.0723990574,-0.0308351479,0.0575400926,0.0180797223,-0.0235445909,-0.0206735581,0.0148384236,-0.0301174279,-0.0405051783,0.0005752286,0.0343372114,-0.0058549936,-0.0784126893,-0.0636729747,-0.0408810601,-0.0238575526,0.0226222556,0.050668709,0.0151783209,0.0001675196,0.0469796918,0.001648635,-0.0132559184,0.0106282569,-0.0456846356,0.0127996132,-0.0125993527,0.0058746799,-0.0025804883,0.0198072549,0.0347900912,-0.0384252481,-0.022840023,0.0428690501,0.012363865,-0.017233571,-0.0179298837,0.0635162517,0.018387273,0.006770289,0.0349081233,0.031577386,-0.062586233,0.0058660838,0.0001465048,-0.008990692,-0.1473801285,-0.0399105251,0.0996709019,-0.0185563136,0.0334621184,-0.000722993,0.0094706155,-0.0064390958,-0.0192250907,0.0175691638,0.0462276302,-0.055475682,-0.0087399259,0.0051764105,-0.0
! gsutil mb -l $LOCATION -p {PROJECT_ID} {BUCKET_URI}
! gsutil cp codeexplanation.json {BUCKET_URI}
# Out:
# Creating gs://qwiklabs-asl-04-06351f77b64f-embvs-codeexplanation/...
# Copying file://codeexplanation.json [Content-Type=application/json]...
# / [1 files][915.1 KiB/915.1 KiB]
# Operation completed over 1 objects/915.1 KiB.

# %%
df.head()
# Out:
#       table_schema                          table_name  \
# 0  rax_bq_metadata                         account_ran
# 1  rax_bq_metadata        email_apps_tax_detail_report
# 2  rax_bq_metadata  dctm_comments_assignments_and_work
# 3  rax_bq_metadata                               wismo
# 4  rax_bq_metadata          bt_pipeline_waterfall_week
#
#                                                  ddl  id
# 0  CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...   0
# 1  CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...   1
# 2  CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...   2
# 3  CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...   3
# 4  CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax...   4

# %%
import os
BUCKET_URI = f"gs://{PROJECT_ID}-embvs-codeexplanation"
DOCUMENT_URI = os.path.join(BUCKET_URI, "documents")

for index, row in df.iterrows():
    path = f"./documents/{row.id}.txt"
    f = open(path, mode="w")
    f.write(row.ddl)
    gcspath = f"{DOCUMENT_URI}/{row.id}"
    # !gsutil cp {path} {gcspath}

# %% [markdown]
# **Create Index**

# %%
# init the aiplatform package
from google.cloud import aiplatform
aiplatform.init(project=PROJECT_ID, location=LOCATION)

# %% [markdown]
# Create Vector Search with create_tree_ah_index function

# %%
# create index
my_index = aiplatform.MatchingEngineIndex.create_tree_ah_index(
    display_name = f"embvs-codeexplanation-index-{UID}",
    contents_delta_uri = BUCKET_URI,
    dimensions = 768,
    approximate_neighbors_count = 20,
    distance_measure_type = "DOT_PRODUCT_DISTANCE",
)
# Out:
# Creating MatchingEngineIndex
# Create MatchingEngineIndex backing LRO: projects/386130433895/locations/us-central1/indexes/3609709868128141312/operations/8343962227274940416
# MatchingEngineIndex created. Resource name: projects/386130433895/locations/us-central1/indexes/3609709868128141312
# To use this MatchingEngineIndex in another session:
# index = aiplatform.MatchingEngineIndex('projects/386130433895/locations/us-central1/indexes/3609709868128141312')

# %% [markdown]
# **Create Index Endpoint and deploy the Index**

# %%
# create IndexEndpoint
my_index_endpoint = aiplatform.MatchingEngineIndexEndpoint.create(
  display_name = f"embvs-codeexplanation-index-endpoint-{UID}",
  public_endpoint_enabled = True,
)
# Out:
# Creating MatchingEngineIndexEndpoint
# Create MatchingEngineIndexEndpoint backing LRO: projects/386130433895/locations/us-central1/indexEndpoints/8823752336716333056/operations/5038320100784996352
# MatchingEngineIndexEndpoint created. Resource name: projects/386130433895/locations/us-central1/indexEndpoints/8823752336716333056
# To use this MatchingEngineIndexEndpoint in another session:
# index_endpoint = aiplatform.MatchingEngineIndexEndpoint('projects/386130433895/locations/us-central1/indexEndpoints/8823752336716333056')

# %%
index_endpoint = aiplatform.MatchingEngineIndexEndpoint('projects/386130433895/locations/us-central1/indexEndpoints/8823752336716333056')
index_endpoint
# Out:
# <google.cloud.aiplatform.matching_engine.matching_engine_index_endpoint.MatchingEngineIndexEndpoint object at 0x7fced4f6ff10>
# resource name: projects/386130433895/locations/us-central1/indexEndpoints/8823752336716333056

# %% [markdown]
# With the Index Endpoint, deploy the Index by specifying an unique deployed index ID

# %%
DEPLOYED_INDEX_ID = f"embvs_codeexplanation_deployed_{UID}"

# %%
# deploy the Index to the Index Endpoint
my_index_endpoint.deploy_index(
  index = my_index, deployed_index_id = DEPLOYED_INDEX_ID
)
# Out:
# Deploying index MatchingEngineIndexEndpoint index_endpoint: projects/386130433895/locations/us-central1/indexEndpoints/8823752336716333056
# Deploy index MatchingEngineIndexEndpoint index_endpoint backing LRO: projects/386130433895/locations/us-central1/indexEndpoints/8823752336716333056/operations/8905786280789409792
# MatchingEngineIndexEndpoint index_endpoint Deployed index. Resource name: projects/386130433895/locations/us-central1/indexEndpoints/8823752336716333056
# <google.cloud.aiplatform.matching_engine.matching_engine_index_endpoint.MatchingEngineIndexEndpoint object at 0x7fced50676d0>
# resource name: projects/386130433895/locations/us-central1/indexEndpoints/8823752336716333056

# %% [markdown]
# **Testing**

# %%
test_embeddings = get_embeddings_wrapper(["What is Call Metrics?"])
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]

# %%
# Test query
response = my_index_endpoint.find_neighbors(
  deployed_index_id = DEPLOYED_INDEX_ID,
  queries = test_embeddings,
  num_neighbors = 5,
)

# show the result
import numpy as np
for idx, neighbor in enumerate(response[0]):
    id = np.int64(neighbor.id)
    similar = df.query("id == @id", engine = "python")
    print(f"{neighbor.distance:.4f} {similar.ddl.values[0]}")
# Out:
# 0.6291 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.customer_call_experience_finding_right_queue_attributes`
# (
#   frq_experience_contact_id STRING,
#   finding_right_queue STRING,
#   total_attempts INT64,
#   same_queue_contact STRING,
#   total_handled_contact_ids INT64,
#   sum_queue_duration INT64,
#   sum_agent_interaction_duration INT64
# )
# CLUSTER BY finding_right_queue;
# 0.6182 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.call_availability_metrics_agent_metrics`
# (
#   _tmk_sso STRING,
#   racker_start_time_key STRING,
#   start_time_key_cst INT64,
#   start_minute INT64,
#   agent_sso STRING,
#   start_datetime_utc DATETIME,
#   start_hour_utc INT64,
#   start_hour_minute_utc TIME,
#   start_datetime_cst DATETIME,
#   start_hour_cst INT64,
#   start_hour_minute_cst TIME,
#   end_datetime_cst DATETIME,
#   agent_time_key STRING,
#   routing_profile STRING,
#   routing_profile_group STRING,
#   agent_answer_rate STRING,
#   occupancy STRING,
#   contacts_agent_hung_up_first INT64,
#   contacts_handled INT64,
#   contacts_handled_incoming INT64,
#   contacts_handled_outbound INT64,
#   callback_contacts_handled INT64,
#   api_contacts_handled INT64,
#   contacts_put_on_hold INT64,
#   contacts_hold_disconnect INT64,
#   contacts_hold_agent_disconnect INT64,
#   contacts_hold_customer_disconnect INT64,
#   contacts_incoming INT64,
#   callback_contacts INT64,
#   api_contacts INT64,
#   contacts_queued INT64,
#   contacts_transferred_in INT64,
#   contacts_transferred_out INT64,
#   contacts_transferred_out_internal INT64,
#   contacts_transferred_out_external INT64,
#   contacts_transferred_in_from_queue INT64,
#   contacts_transferred_out_from_queue INT64,
#   contacts_missed INT64,
#   customer_hold_time INT64,
#   contact_handle_time INT64,
#   contact_flow_time INT64,
#   agent_interaction_and_hold_time INT64,
#   agent_interaction_time INT64,
#   after_contact_work_time INT64,
#   nonproductive_time INT64,
#   online_time INT64,
#   agent_on_contact_time INT64,
#   agent_idle_time INT64,
#   aux_02_break_time INT64,
#   aux_03_lunch_time INT64,
#   aux_04_meeting_time INT64,
#   aux_05_assist_time INT64,
#   aux_06_training_time INT64,
#   aux_07_project_time INT64,
#   aux_08_maintenance_time INT64,
#   aux_09_chat_time INT64,
#   aux_10_critical_time INT64,
#   conference_time INT64,
#   no_call_time INT64,
#   rona_time INT64,
#   error_status_time INT64,
#   shift_prep_wrap_time INT64
# )
# PARTITION BY DATETIME_TRUNC(start_datetime_utc, MONTH)
# CLUSTER BY _tmk_sso, routing_profile;
# 0.6105 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.phone_records`
# (
#   initial_contact_id STRING,
#   contact_id STRING,
#   previous_contact_id STRING,
#   next_contact_id STRING,
#   initiation_timestamp_utc TIMESTAMP,
#   agent_connected_to_agent_timestamp_utc TIMESTAMP,
#   connected_to_system_timestamp_utc TIMESTAMP,
#   disconnect_timestamp_utc TIMESTAMP,
#   transfer_completed_timestamp_utc TIMESTAMP,
#   queue_enqueue_timestamp_utc TIMESTAMP,
#   queue_dequeue_timestamp_utc TIMESTAMP,
#   last_update_timestamp_utc TIMESTAMP,
#   username STRING,
#   agent_connection_attempts INT64,
#   agent_interaction_duration INT64,
#   agent_customer_hold_duration INT64,
#   agent_longest_hold_duration INT64,
#   agent_number_of_holds INT64,
#   agent_routing_profile_name STRING,
#   local_ivr STRING,
#   global_landing STRING,
#   customer_endpoint_address STRING,
#   initiation_method STRING,
#   queue_duration INT64,
#   queue_name STRING,
#   system_endpoint_address STRING,
#   transferred_to_endpoint_address STRING,
#   transferred_to_endpoint_type STRING,
#   handled STRING,
#   abandon STRING,
#   transfered_exist_timestamp STRING,
#   account_number STRING,
#   account_type STRING,
#   interaction_id STRING,
#   reason STRING,
#   support_tier STRING,
#   userid STRING,
#   interaction_logged STRING,
#   queue_arn STRING,
#   agent_arn STRING,
#   agent_after_contact_work_duration INT64,
#   after_contact_work_start_timestamp_utc TIMESTAMP,
#   after_contact_work_end_timestamp_utc TIMESTAMP,
#   sla_measured INT64,
#   transfer_accepted STRING,
#   version STRING,
#   pcs_offered BOOL,
#   ces_response INT64,
#   csat_response INT64,
#   fcr_response STRING,
#   pcs_comments STRING,
#   attributes_global_front_line_lex STRING,
#   attributes_lex_account_lookup STRING,
#   attributes_possible_accounts STRING,
#   attributes_snow_possible_accounts STRING,
#   attributes_rotating_announcement STRING,
#   attributes_queued_callback STRING,
#   attributes_queued_callback_offer BOOL,
#   attributes_queued_callback_opt STRING,
#   attributes_queued_callback_track INT64,
#   attributes_sales_line_destination STRING,
#   ticket_number STRING
# )
# PARTITION BY DATE(initiation_timestamp_utc)
# CLUSTER BY queue_name, initial_contact_id, contact_id, username;
# 0.6049 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.customer_call_experience_interaction_info`
# (
#   interaction_id STRING,
#   interaction_template_id STRING,
#   interaction_logged_by_sso STRING,
#   interaction_support_team STRING,
#   interaction_call_type STRING,
#   interaction_customer_response STRING,
#   interaction_transferred_to STRING,
#   interaction_reason STRING,
#   existing_issue STRING,
#   reference_type STRING,
#   interaction_reference_number STRING
# )
# CLUSTER BY interaction_support_team;
# 0.6016 CREATE TABLE `qwiklabs-asl-04-e7ad74c2e059.rax_bq_metadata.customer_call_experience_first_leg_second_leg`
# (
#   initial_contact_id STRING,
#   interaction_id STRING,
#   initiation_time_key INT64,
#   initiation_timestamp_cst TIMESTAMP,
#   _source_account_number STRING,
#   first_leg_initiation_method STRING,
#   _tmk_sso STRING,
#   first_leg_contact_id STRING,
#   frq_experience_contact_id STRING,
#   customer_experience STRING,
#   first_leg_queue STRING,
#   first_leg_queue_duration INT64,
#   verification_and_scope INT64,
#   first_leg_customer_hold_duration INT64,
#   finding_right_queue_duration INT64,
#   total_frq_attempts INT64,
#   failed_attempts INT64,
#   failed_attempts_timestamp_cst DATETIME,
#   hand_off_seconds INT64,
#   hand_off_type STRING,
#   _alternate_tmk_sso STRING,
#   second_leg_contact_id STRING,
#   second_leg_initiation_method STRING,
#   second_leg_queue STRING,
#   second_leg_queue_duration INT64,
#   second_leg_interaction_duration INT64
# )
# PARTITION BY DATETIME_TRUNC(failed_attempts_timestamp_cst, MONTH)
# CLUSTER BY _tmk_sso, first_leg_queue;

# %%
import sys
# !{sys.executable} -m pip install gradio
# Out:
# Requirement already satisfied: gradio in /opt/conda/lib/python3.10/site-packages (4.4.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (5.1.2)
# Requirement already satisfied: fastapi in /opt/conda/lib/python3.10/site-packages (from gradio) (0.103.1)
# Requirement already satisfied: ffmpy in /opt/conda/lib/python3.10/site-packages (from gradio) (0.3.1)
# Requirement already satisfied: gradio-client==0.7.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (0.7.0)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.10/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: huggingface-hub>=0.14.0 in /home/jupyter/.local/lib/python3.10/site-packages (from gradio) (0.17.2)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /opt/conda/lib/python3.10/site-packages (from gradio) (6.1.0)
# Requirement already satisfied: jinja2<4.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (2.0.1)
# Requirement already satisfied: matplotlib~=3.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (3.8.0)
# Requirement already satisfied: numpy~=1.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (1.23.5)
# Requirement already satisfied: orjson~=3.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (3.9.7)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from gradio) (23.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (2.0.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (10.0.1)
# Requirement already satisfied: pydantic>=2.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (2.5.1)
# Requirement already satisfied: pydub in /opt/conda/lib/python3.10/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart in /opt/conda/lib/python3.10/site-packages (from gradio) (0.0.6)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /home/jupyter/.local/lib/python3.10/site-packages (from gradio) (5.3.1)
# Requirement already satisfied: requests~=2.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (2.31.0)
# Requirement already satisfied: semantic-version~=2.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.9 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio) (0.9.0)
# Requirement already satisfied: typing-extensions~=4.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (4.8.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (0.23.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from gradio-client==0.7.0->gradio) (2023.9.2)
# Requirement already satisfied: websockets<12.0,>=10.0 in /opt/conda/lib/python3.10/site-packages (from gradio-client==0.7.0->gradio) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in /opt/conda/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio) (4.19.1)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.14.0->gradio) (3.12.4)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.14.0->gradio) (4.66.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.3 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2.0->gradio) (2.14.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests~=2.0->gradio) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests~=2.0->gradio) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests~=2.0->gradio) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests~=2.0->gradio) (2023.7.22)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.10/site-packages (from typer<1.0,>=0.9->typer[all]<1.0,>=0.9->gradio) (8.1.7)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio) (13.5.3)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.10/site-packages (from uvicorn>=0.14.0->gradio) (0.14.0)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /opt/conda/lib/python3.10/site-packages (from fastapi->gradio) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /opt/conda/lib/python3.10/site-packages (from fastapi->gradio) (0.27.0)
# Requirement already satisfied: httpcore in /opt/conda/lib/python3.10/site-packages (from httpx->gradio) (1.0.2)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from anyio<4.0.0,>=3.7.1->fastapi->gradio) (1.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.10.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (0.1.2)
